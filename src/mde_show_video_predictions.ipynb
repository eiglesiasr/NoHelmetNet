# %%
import cv2
from ultralytics import YOLO

# %%
video_path = '../raw/Medellin2/IMG_7439.mov'  # 🎥 video en formato .mov
cap = cv2.VideoCapture(video_path)
model = YOLO('../results/yolo_train/exp/weights/best.pt')

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Ejecutar predicción sobre el frame
    results = model.predict(source=frame, conf=0.3, stream=True)

    # Dibujar las cajas en el frame
    for r in results:
        annotated_frame = r.plot()  # Dibuja bounding boxes, etiquetas, etc.

    # Mostrar el frame anotado
    cv2.imshow("Predicción YOLOv8", annotated_frame)

    # Presiona 'q' para salir
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 0: 384x640 (no detections), 80.4ms
# Speed: 5.2ms preprocess, 80.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.4ms
# Speed: 10.3ms preprocess, 69.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.8ms
# Speed: 3.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.7ms
# Speed: 3.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 3.5ms preprocess, 70.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.7ms
# Speed: 10.2ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.8ms
# Speed: 3.3ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# Liberar recursos
cap.release()
cv2.destroyAllWindows()
